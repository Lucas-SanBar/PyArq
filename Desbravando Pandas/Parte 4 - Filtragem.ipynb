# %%
import pandas as pd

# %% [markdown]
# ### Base utilizada

# %%
df_data = pd.read_csv('./Base de dados/ConsumidorGov.csv',sep = ';')

# %% [markdown]
# # Filtragem

# %% [markdown]
# Durante a análise exploratória dos dados, frequentemente será necessário filtrar amostras, a partir de certas condições, para fins de análise mais específica. Existe algumas maneiras de fazermos isso como as mostradas a seguir:

# %% [markdown]
# ### Filtragem condicional direta

# %% [markdown]
# Supondo que nosso objetivo seja trazer apenas as reclamações do site "ConsumidorGov" do estádo **GOIÁS**, como seria feito?

# %% [markdown]
# Para fazer essa selação condicional, é necessário buscar o descritivo que representa **SÃO PAULO** e como esta escrita dentro da massa de dados, neste caso utilizaremos a seleção da coluna `UF` juntamente com o método `unique()`, este é responsável por trazer uma array com os campos **distintos** para cada valor do campo selecionado.

# %%
## Mostra todos os estados com reclamações no site "Consumidor Gov".
## Mostra os únicos (unique) valores para a coluna 'UF'.
df_data['UF'].unique()
# Out:
# array(['AL', 'PE', 'BA', 'SP', 'MT', 'PR', 'PA', 'RN', 'RJ', 'MG', 'RS',
#        'SE', 'CE', 'GO', 'DF', 'ES', 'MS', 'PB', 'MA', 'AP', 'SC', 'RO',
#        'TO', 'PI', 'AC', 'AM', 'RR'], dtype=object)

# %% [markdown]
# Podemos observar que o nosso objetivo então é fazer a filtragem condicional/direta utilizando o valor 'SP' da coluna `UF`. Podemos fazer isto da seguinte forma:

# %%
## Comparação da coluna 'UF' com o valor 'SP'
df_data['UF'] == 'SP'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4          True
#           ...
# 105013    False
# 105014    False
# 105015    False
# 105016    False
# 105017    False
# Name: UF, Length: 105018, dtype: bool

# %% [markdown]
# Repare que o retorno é feito __**linha a linha**__ através de uma Series('array') de **booleans** mostrando se a linha em questão respeita(**TRUE**) ou não respeita(**FALSE**) a condição proposta `UF = 'SP'`.

# %% [markdown]
# Como filtrar então o DataFrame `df_data` para obter apenas as linhas que contém o campo `UF` igual a 'SP'?

# %%
## Armazenando a series retornada em uma variável
selecao = df_data['UF'] == 'SP'
selecao
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4          True
#           ...
# 105013    False
# 105014    False
# 105015    False
# 105016    False
# 105017    False
# Name: UF, Length: 105018, dtype: bool

# %% [markdown]
# Utilizaremos a Series criada `selecao` para filtragem no DataFrame `df_data`

# %%
df_data[selecao] ## Aplicando a filtragem em todos os registros do DataFrame 'df_data' utilizando a series de booleano 'selecao'
# Out:
#                                              Gestor Canal de Origem Região  \
# 4       Fundação de Proteção e Defesa do Consumidor  Plataforma Web     SE
# 22      Fundação de Proteção e Defesa do Consumidor  Plataforma Web     SE
# 28      Fundação de Proteção e Defesa do Consumidor  Plataforma Web     SE
# 34      Fundação de Proteção e Defesa do Consumidor  Plataforma Web     SE
# 35      Fundação de Proteção e Defesa do Consumidor  Plataforma Web     SE
# ...                                             ...             ...    ...
# 104926  Fundação de Proteção e Defesa do Consumidor  Plataforma Web     SE
# 104932  Fundação de Proteção e Defesa do Consumidor  Plataforma Web     SE
# 104953  Fundação de Proteção e Defesa do Consumidor  Plataforma Web     SE
# 104958  Fundação de Proteção e Defesa do Consumidor  Plataforma Web     SE
# 104964  Fundação de Proteção e Defesa do Consumidor  Plataforma Web     SE
#
#         UF          Cidade Sexo        Faixa Etária  Ano Abertura  \
# 4       SP         Guarujá    M  entre 51 a 60 anos          2024
# 22      SP          Osasco    M  entre 41 a 50 anos          2024
# 28      SP       São Paulo    M  entre 31 a 40 anos          2024
# 34      SP        Itanhaém    M  entre 51 a 60 anos          2024
# 35      SP     Santo André    M  entre 61 a 70 anos          2024
# ...     ..             ...  ...                 ...           ...
# 104926  SP     Carapicuíba    M  entre 31 a 40 anos          2024
# 104932  SP         Diadema    M  entre 21 a 30 anos          2024
# 104953  SP  Ribeirão Preto    F  entre 21 a 30 anos          2024
# 104958  SP       São Paulo    M  entre 31 a 40 anos          2024
# 104964  SP        Campinas    M  entre 31 a 40 anos          2024
#
#         Mês Abertura Data Abertura  ...  \
# 4                 10    01/10/2024  ...
# 22                10    02/10/2024  ...
# 28                10    02/10/2024  ...
# 34                10    03/10/2024  ...
# 35                10    03/10/2024  ...
# ...              ...           ...  ...
# 104926            12    29/12/2024  ...
# 104932            12    30/12/2024  ...
# 104953            12    30/12/2024  ...
# 104958            12    30/12/2024  ...
# 104964            12    30/12/2024  ...
#
#                                                   Assunto  \
# 4                                           Água e Esgoto
# 22      Cartão de Crédito / Cartão de Débito / Cartão ...
# 28                        Aplicativo de mobilidade urbana
# 34          Produtos Veterinários (ração, acessórios etc)
# 35                                       Energia Elétrica
# ...                                                   ...
# 104926                              Serviços Veterinários
# 104932  Cartão de Crédito / Cartão de Débito / Cartão ...
# 104953             Pacote / excursão / agência de turismo
# 104958  Cartão de Crédito / Cartão de Débito / Cartão ...
# 104964                                              Aéreo
#
#                 Grupo Problema  \
# 4            Atendimento / SAC
# 22           Contrato / Oferta
# 28      Cobrança / Contestação
# 34      Cobrança / Contestação
# 35      Cobrança / Contestação
# ...                        ...
# 104926       Atendimento / SAC
# 104932  Cobrança / Contestação
# 104953  Cobrança / Contestação
# 104958  Cobrança / Contestação
# 104964              Informação
#
#                                                  Problema  \
# 4       Má qualidade no atendimento (descortesia / des...
# 22      Oferta não cumprida / serviço não fornecido/ v...
# 28      Cobrança de tarifas, taxas, valores não previs...
# 34      Cobrança em duplicidade / Cobrança referente a...
# 35      C?obrança de participação financeira em obra? ...
# ...                                                   ...
# 104926  Má qualidade no atendimento (descortesia / des...
# 104932  Negativação indevida referente à pagamento já ...
# 104953  Dificuldade / atraso na devolução de valores p...
# 104958  Negativação indevida referente à pagamento já ...
# 104964  Informações incompletas / inadequadas sobre o ...
#
#          Como Comprou Contratou Procurou Empresa  Respondida  \
# 4                   Loja física                S           S
# 22                     Internet                S           S
# 28                     Internet                S           S
# 34                     Internet                S           S
# 35                    Domicílio                S           S
# ...                         ...              ...         ...
# 104926  Não comprei / contratei                S           S
# 104932                 Internet                S           S
# 104953                 Internet                S           S
# 104958  Não comprei / contratei                S           S
# 104964                 Internet                S           S
#
#                    Situação Avaliação Reclamação Nota do Consumidor  \
# 4       Finalizada avaliada            Resolvida                3.0
# 22      Finalizada avaliada            Resolvida                4.0
# 28      Finalizada avaliada        Não Resolvida                1.0
# 34      Finalizada avaliada            Resolvida                1.0
# 35      Finalizada avaliada        Não Resolvida                1.0
# ...                     ...                  ...                ...
# 104926  Finalizada avaliada        Não Resolvida                1.0
# 104932  Finalizada avaliada            Resolvida                5.0
# 104953  Finalizada avaliada        Não Resolvida                1.0
# 104958  Finalizada avaliada            Resolvida                5.0
# 104964  Finalizada avaliada            Resolvida                5.0
#
#        Análise da Recusa
# 4                    NaN
# 22                   NaN
# 28                   NaN
# 34                   NaN
# 35                   NaN
# ...                  ...
# 104926               NaN
# 104932               NaN
# 104953               NaN
# 104958               NaN
# 104964               NaN
#
# [25691 rows x 30 columns]

# %% [markdown]
# Desta forma, o retorno do DataFrame é apenas com as linhas onde o campo `UF` é igual a **'SP'**

# %% [markdown]
# **OBSEVAÇÃO : **Também é possível utilizando o comando `.loc[selecao]` para obter o mesmo resultado.

# %% [markdown]
# ### Filtragem com método Query

# %% [markdown]
# Também é possível utilizar o método `query`, este filtra linhas de um DataFrame baseando-se em uma **pergunta(Query)**.

# %%
df_data.query('UF == "SP"')
# Out:
#                                              Gestor Canal de Origem Região  \
# 4       Fundação de Proteção e Defesa do Consumidor  Plataforma Web     SE
# 22      Fundação de Proteção e Defesa do Consumidor  Plataforma Web     SE
# 28      Fundação de Proteção e Defesa do Consumidor  Plataforma Web     SE
# 34      Fundação de Proteção e Defesa do Consumidor  Plataforma Web     SE
# 35      Fundação de Proteção e Defesa do Consumidor  Plataforma Web     SE
# ...                                             ...             ...    ...
# 104926  Fundação de Proteção e Defesa do Consumidor  Plataforma Web     SE
# 104932  Fundação de Proteção e Defesa do Consumidor  Plataforma Web     SE
# 104953  Fundação de Proteção e Defesa do Consumidor  Plataforma Web     SE
# 104958  Fundação de Proteção e Defesa do Consumidor  Plataforma Web     SE
# 104964  Fundação de Proteção e Defesa do Consumidor  Plataforma Web     SE
#
#         UF          Cidade Sexo        Faixa Etária  Ano Abertura  \
# 4       SP         Guarujá    M  entre 51 a 60 anos          2024
# 22      SP          Osasco    M  entre 41 a 50 anos          2024
# 28      SP       São Paulo    M  entre 31 a 40 anos          2024
# 34      SP        Itanhaém    M  entre 51 a 60 anos          2024
# 35      SP     Santo André    M  entre 61 a 70 anos          2024
# ...     ..             ...  ...                 ...           ...
# 104926  SP     Carapicuíba    M  entre 31 a 40 anos          2024
# 104932  SP         Diadema    M  entre 21 a 30 anos          2024
# 104953  SP  Ribeirão Preto    F  entre 21 a 30 anos          2024
# 104958  SP       São Paulo    M  entre 31 a 40 anos          2024
# 104964  SP        Campinas    M  entre 31 a 40 anos          2024
#
#         Mês Abertura Data Abertura  ...  \
# 4                 10    01/10/2024  ...
# 22                10    02/10/2024  ...
# 28                10    02/10/2024  ...
# 34                10    03/10/2024  ...
# 35                10    03/10/2024  ...
# ...              ...           ...  ...
# 104926            12    29/12/2024  ...
# 104932            12    30/12/2024  ...
# 104953            12    30/12/2024  ...
# 104958            12    30/12/2024  ...
# 104964            12    30/12/2024  ...
#
#                                                   Assunto  \
# 4                                           Água e Esgoto
# 22      Cartão de Crédito / Cartão de Débito / Cartão ...
# 28                        Aplicativo de mobilidade urbana
# 34          Produtos Veterinários (ração, acessórios etc)
# 35                                       Energia Elétrica
# ...                                                   ...
# 104926                              Serviços Veterinários
# 104932  Cartão de Crédito / Cartão de Débito / Cartão ...
# 104953             Pacote / excursão / agência de turismo
# 104958  Cartão de Crédito / Cartão de Débito / Cartão ...
# 104964                                              Aéreo
#
#                 Grupo Problema  \
# 4            Atendimento / SAC
# 22           Contrato / Oferta
# 28      Cobrança / Contestação
# 34      Cobrança / Contestação
# 35      Cobrança / Contestação
# ...                        ...
# 104926       Atendimento / SAC
# 104932  Cobrança / Contestação
# 104953  Cobrança / Contestação
# 104958  Cobrança / Contestação
# 104964              Informação
#
#                                                  Problema  \
# 4       Má qualidade no atendimento (descortesia / des...
# 22      Oferta não cumprida / serviço não fornecido/ v...
# 28      Cobrança de tarifas, taxas, valores não previs...
# 34      Cobrança em duplicidade / Cobrança referente a...
# 35      C?obrança de participação financeira em obra? ...
# ...                                                   ...
# 104926  Má qualidade no atendimento (descortesia / des...
# 104932  Negativação indevida referente à pagamento já ...
# 104953  Dificuldade / atraso na devolução de valores p...
# 104958  Negativação indevida referente à pagamento já ...
# 104964  Informações incompletas / inadequadas sobre o ...
#
#          Como Comprou Contratou Procurou Empresa  Respondida  \
# 4                   Loja física                S           S
# 22                     Internet                S           S
# 28                     Internet                S           S
# 34                     Internet                S           S
# 35                    Domicílio                S           S
# ...                         ...              ...         ...
# 104926  Não comprei / contratei                S           S
# 104932                 Internet                S           S
# 104953                 Internet                S           S
# 104958  Não comprei / contratei                S           S
# 104964                 Internet                S           S
#
#                    Situação Avaliação Reclamação Nota do Consumidor  \
# 4       Finalizada avaliada            Resolvida                3.0
# 22      Finalizada avaliada            Resolvida                4.0
# 28      Finalizada avaliada        Não Resolvida                1.0
# 34      Finalizada avaliada            Resolvida                1.0
# 35      Finalizada avaliada        Não Resolvida                1.0
# ...                     ...                  ...                ...
# 104926  Finalizada avaliada        Não Resolvida                1.0
# 104932  Finalizada avaliada            Resolvida                5.0
# 104953  Finalizada avaliada        Não Resolvida                1.0
# 104958  Finalizada avaliada            Resolvida                5.0
# 104964  Finalizada avaliada            Resolvida                5.0
#
#        Análise da Recusa
# 4                    NaN
# 22                   NaN
# 28                   NaN
# 34                   NaN
# 35                   NaN
# ...                  ...
# 104926               NaN
# 104932               NaN
# 104953               NaN
# 104958               NaN
# 104964               NaN
#
# [25691 rows x 30 columns]

# %% [markdown]
# Uma boa prática é sempre salvar o DataFrame em uma nova variável. Isso simplifica a complexidade do código para futuras análises feitas.

# %%
consumidor_sp = df_data.query('UF == "SP"')
consumidor_sp
# Out:
#                                              Gestor Canal de Origem Região  \
# 4       Fundação de Proteção e Defesa do Consumidor  Plataforma Web     SE
# 22      Fundação de Proteção e Defesa do Consumidor  Plataforma Web     SE
# 28      Fundação de Proteção e Defesa do Consumidor  Plataforma Web     SE
# 34      Fundação de Proteção e Defesa do Consumidor  Plataforma Web     SE
# 35      Fundação de Proteção e Defesa do Consumidor  Plataforma Web     SE
# ...                                             ...             ...    ...
# 104926  Fundação de Proteção e Defesa do Consumidor  Plataforma Web     SE
# 104932  Fundação de Proteção e Defesa do Consumidor  Plataforma Web     SE
# 104953  Fundação de Proteção e Defesa do Consumidor  Plataforma Web     SE
# 104958  Fundação de Proteção e Defesa do Consumidor  Plataforma Web     SE
# 104964  Fundação de Proteção e Defesa do Consumidor  Plataforma Web     SE
#
#         UF          Cidade Sexo        Faixa Etária  Ano Abertura  \
# 4       SP         Guarujá    M  entre 51 a 60 anos          2024
# 22      SP          Osasco    M  entre 41 a 50 anos          2024
# 28      SP       São Paulo    M  entre 31 a 40 anos          2024
# 34      SP        Itanhaém    M  entre 51 a 60 anos          2024
# 35      SP     Santo André    M  entre 61 a 70 anos          2024
# ...     ..             ...  ...                 ...           ...
# 104926  SP     Carapicuíba    M  entre 31 a 40 anos          2024
# 104932  SP         Diadema    M  entre 21 a 30 anos          2024
# 104953  SP  Ribeirão Preto    F  entre 21 a 30 anos          2024
# 104958  SP       São Paulo    M  entre 31 a 40 anos          2024
# 104964  SP        Campinas    M  entre 31 a 40 anos          2024
#
#         Mês Abertura Data Abertura  ...  \
# 4                 10    01/10/2024  ...
# 22                10    02/10/2024  ...
# 28                10    02/10/2024  ...
# 34                10    03/10/2024  ...
# 35                10    03/10/2024  ...
# ...              ...           ...  ...
# 104926            12    29/12/2024  ...
# 104932            12    30/12/2024  ...
# 104953            12    30/12/2024  ...
# 104958            12    30/12/2024  ...
# 104964            12    30/12/2024  ...
#
#                                                   Assunto  \
# 4                                           Água e Esgoto
# 22      Cartão de Crédito / Cartão de Débito / Cartão ...
# 28                        Aplicativo de mobilidade urbana
# 34          Produtos Veterinários (ração, acessórios etc)
# 35                                       Energia Elétrica
# ...                                                   ...
# 104926                              Serviços Veterinários
# 104932  Cartão de Crédito / Cartão de Débito / Cartão ...
# 104953             Pacote / excursão / agência de turismo
# 104958  Cartão de Crédito / Cartão de Débito / Cartão ...
# 104964                                              Aéreo
#
#                 Grupo Problema  \
# 4            Atendimento / SAC
# 22           Contrato / Oferta
# 28      Cobrança / Contestação
# 34      Cobrança / Contestação
# 35      Cobrança / Contestação
# ...                        ...
# 104926       Atendimento / SAC
# 104932  Cobrança / Contestação
# 104953  Cobrança / Contestação
# 104958  Cobrança / Contestação
# 104964              Informação
#
#                                                  Problema  \
# 4       Má qualidade no atendimento (descortesia / des...
# 22      Oferta não cumprida / serviço não fornecido/ v...
# 28      Cobrança de tarifas, taxas, valores não previs...
# 34      Cobrança em duplicidade / Cobrança referente a...
# 35      C?obrança de participação financeira em obra? ...
# ...                                                   ...
# 104926  Má qualidade no atendimento (descortesia / des...
# 104932  Negativação indevida referente à pagamento já ...
# 104953  Dificuldade / atraso na devolução de valores p...
# 104958  Negativação indevida referente à pagamento já ...
# 104964  Informações incompletas / inadequadas sobre o ...
#
#          Como Comprou Contratou Procurou Empresa  Respondida  \
# 4                   Loja física                S           S
# 22                     Internet                S           S
# 28                     Internet                S           S
# 34                     Internet                S           S
# 35                    Domicílio                S           S
# ...                         ...              ...         ...
# 104926  Não comprei / contratei                S           S
# 104932                 Internet                S           S
# 104953                 Internet                S           S
# 104958  Não comprei / contratei                S           S
# 104964                 Internet                S           S
#
#                    Situação Avaliação Reclamação Nota do Consumidor  \
# 4       Finalizada avaliada            Resolvida                3.0
# 22      Finalizada avaliada            Resolvida                4.0
# 28      Finalizada avaliada        Não Resolvida                1.0
# 34      Finalizada avaliada            Resolvida                1.0
# 35      Finalizada avaliada        Não Resolvida                1.0
# ...                     ...                  ...                ...
# 104926  Finalizada avaliada        Não Resolvida                1.0
# 104932  Finalizada avaliada            Resolvida                5.0
# 104953  Finalizada avaliada        Não Resolvida                1.0
# 104958  Finalizada avaliada            Resolvida                5.0
# 104964  Finalizada avaliada            Resolvida                5.0
#
#        Análise da Recusa
# 4                    NaN
# 22                   NaN
# 28                   NaN
# 34                   NaN
# 35                   NaN
# ...                  ...
# 104926               NaN
# 104932               NaN
# 104953               NaN
# 104958               NaN
# 104964               NaN
#
# [25691 rows x 30 columns]

# %% [markdown]
# Note, que os índices das linhas mesmo após a filtragem continuam sendo os mesmos do DataFrame `df_data`. Em algumas situações, manter esta informação é importante.

# %% [markdown]
# Caso seja necessário *resetar os índices* do Data Frame novo filtrado, use o método `reset_index`.

# %%
consumidor_sp.reset_index().head()
# Out:
#    index                                       Gestor Canal de Origem Região  \
# 0      4  Fundação de Proteção e Defesa do Consumidor  Plataforma Web     SE
# 1     22  Fundação de Proteção e Defesa do Consumidor  Plataforma Web     SE
# 2     28  Fundação de Proteção e Defesa do Consumidor  Plataforma Web     SE
# 3     34  Fundação de Proteção e Defesa do Consumidor  Plataforma Web     SE
# 4     35  Fundação de Proteção e Defesa do Consumidor  Plataforma Web     SE
#
#    UF       Cidade Sexo        Faixa Etária  Ano Abertura  Mês Abertura  ...  \
# 0  SP      Guarujá    M  entre 51 a 60 anos          2024            10  ...
# 1  SP       Osasco    M  entre 41 a 50 anos          2024            10  ...
# 2  SP    São Paulo    M  entre 31 a 40 anos          2024            10  ...
# 3  SP     Itanhaém    M  entre 51 a 60 anos          2024            10  ...
# 4  SP  Santo André    M  entre 61 a 70 anos          2024            10  ...
#
#                                              Assunto          Grupo Problema  \
# 0                                      Água e Esgoto       Atendimento / SAC
# 1  Cartão de Crédito / Cartão de Débito / Cartão ...       Contrato / Oferta
# 2                    Aplicativo de mobilidade urbana  Cobrança / Contestação
# 3      Produtos Veterinários (ração, acessórios etc)  Cobrança / Contestação
# 4                                   Energia Elétrica  Cobrança / Contestação
#
#                                             Problema Como Comprou Contratou  \
# 0  Má qualidade no atendimento (descortesia / des...            Loja física
# 1  Oferta não cumprida / serviço não fornecido/ v...               Internet
# 2  Cobrança de tarifas, taxas, valores não previs...               Internet
# 3  Cobrança em duplicidade / Cobrança referente a...               Internet
# 4  C?obrança de participação financeira em obra? ...              Domicílio
#
#   Procurou Empresa Respondida             Situação  Avaliação Reclamação  \
# 0                S          S  Finalizada avaliada             Resolvida
# 1                S          S  Finalizada avaliada             Resolvida
# 2                S          S  Finalizada avaliada         Não Resolvida
# 3                S          S  Finalizada avaliada             Resolvida
# 4                S          S  Finalizada avaliada         Não Resolvida
#
#   Nota do Consumidor Análise da Recusa
# 0                3.0               NaN
# 1                4.0               NaN
# 2                1.0               NaN
# 3                1.0               NaN
# 4                1.0               NaN
#
# [5 rows x 31 columns]

# %% [markdown]
# Note que o retorno mantém o antigo **INDEX** como coluna, caso você queira remover este do novo DataFrame utilize o parâmetro `drop=True` no método `reset_index()`

# %%
consumidor_sp.reset_index(drop = True).head()
# Out:
#                                         Gestor Canal de Origem Região  UF  \
# 0  Fundação de Proteção e Defesa do Consumidor  Plataforma Web     SE  SP
# 1  Fundação de Proteção e Defesa do Consumidor  Plataforma Web     SE  SP
# 2  Fundação de Proteção e Defesa do Consumidor  Plataforma Web     SE  SP
# 3  Fundação de Proteção e Defesa do Consumidor  Plataforma Web     SE  SP
# 4  Fundação de Proteção e Defesa do Consumidor  Plataforma Web     SE  SP
#
#         Cidade Sexo        Faixa Etária  Ano Abertura  Mês Abertura  \
# 0      Guarujá    M  entre 51 a 60 anos          2024            10
# 1       Osasco    M  entre 41 a 50 anos          2024            10
# 2    São Paulo    M  entre 31 a 40 anos          2024            10
# 3     Itanhaém    M  entre 51 a 60 anos          2024            10
# 4  Santo André    M  entre 61 a 70 anos          2024            10
#
#   Data Abertura  ...                                            Assunto  \
# 0    01/10/2024  ...                                      Água e Esgoto
# 1    02/10/2024  ...  Cartão de Crédito / Cartão de Débito / Cartão ...
# 2    02/10/2024  ...                    Aplicativo de mobilidade urbana
# 3    03/10/2024  ...      Produtos Veterinários (ração, acessórios etc)
# 4    03/10/2024  ...                                   Energia Elétrica
#
#            Grupo Problema                                           Problema  \
# 0       Atendimento / SAC  Má qualidade no atendimento (descortesia / des...
# 1       Contrato / Oferta  Oferta não cumprida / serviço não fornecido/ v...
# 2  Cobrança / Contestação  Cobrança de tarifas, taxas, valores não previs...
# 3  Cobrança / Contestação  Cobrança em duplicidade / Cobrança referente a...
# 4  Cobrança / Contestação  C?obrança de participação financeira em obra? ...
#
#   Como Comprou Contratou Procurou Empresa  Respondida             Situação  \
# 0            Loja física                S           S  Finalizada avaliada
# 1               Internet                S           S  Finalizada avaliada
# 2               Internet                S           S  Finalizada avaliada
# 3               Internet                S           S  Finalizada avaliada
# 4              Domicílio                S           S  Finalizada avaliada
#
#   Avaliação Reclamação Nota do Consumidor Análise da Recusa
# 0            Resolvida                3.0               NaN
# 1            Resolvida                4.0               NaN
# 2        Não Resolvida                1.0               NaN
# 3            Resolvida                1.0               NaN
# 4        Não Resolvida                1.0               NaN
#
# [5 rows x 30 columns]

# %% [markdown]
# **OBSEVAÇÃO :** O DataFrame `consumidor_sp` não foi alterado, caso seja necessário alterar é preciso utilizar o parâmetro `inplace=True`.

# %% [markdown]
# ### Filtragem com multiplas condicionais

# %% [markdown]
# Em Pandas, você pode filtrar um DataFrame com múltiplas condições usando operadores lógicos como:
# * `&` **(AND)** → Ambas as condições devem ser verdadeiras;
# * `|` **(OR)** → Ao menos uma condição deve ser verdadeira;
# * `~` **(NOT)** → Inverte a condição;
#
# **É importante que cada condição esteja em parênteses**

# %% [markdown]
# Por exemplo, se quisermos todas as reclamações do .csv do **Consumidor GOV** do estado de **GOIÁS (GO)** que contenha nota menor ou igual a 3, podemos obter esse retorno da seguinte forma:

# %%
df_data[(df_data['UF'] == 'GO') & (df_data['Nota do Consumidor'] <= 3.0)] ##Consumidor GOV do estado de GOIÁS (GO) que contenha nota menor ou igual a 3
# Out:
#                                                    Gestor Canal de Origem  \
# 18      Superintendência de Proteção e Defesa do Consu...  Plataforma Web
# 19      Superintendência de Proteção e Defesa do Consu...  Plataforma Web
# 20      Superintendência de Proteção e Defesa do Consu...  Plataforma Web
# 21      Superintendência de Proteção e Defesa do Consu...  Plataforma Web
# 60      Superintendência de Proteção e Defesa do Consu...  Plataforma Web
# ...                                                   ...             ...
# 104606  Superintendência de Proteção e Defesa do Consu...  Plataforma Web
# 104712  Superintendência de Proteção e Defesa do Consu...  Plataforma Web
# 104727  Superintendência de Proteção e Defesa do Consu...  Plataforma Web
# 104943  Superintendência de Proteção e Defesa do Consu...  Plataforma Web
# 104960  Superintendência de Proteção e Defesa do Consu...  Plataforma Web
#
#        Região  UF                 Cidade Sexo        Faixa Etária  \
# 18         CO  GO               Anápolis    M  entre 21 a 30 anos
# 19         CO  GO               Anápolis    M  entre 21 a 30 anos
# 20         CO  GO               Anápolis    M  entre 21 a 30 anos
# 21         CO  GO               Anápolis    M  entre 21 a 30 anos
# 60         CO  GO                Goiânia    M  entre 41 a 50 anos
# ...       ...  ..                    ...  ...                 ...
# 104606     CO  GO                Goiânia    M  entre 41 a 50 anos
# 104712     CO  GO    Valparaíso de Goiás    M  entre 31 a 40 anos
# 104727     CO  GO  Santa Helena de Goiás    M  entre 31 a 40 anos
# 104943     CO  GO         Senador Canedo    M  entre 31 a 40 anos
# 104960     CO  GO               Anápolis    M  entre 31 a 40 anos
#
#         Ano Abertura  Mês Abertura Data Abertura  ...  \
# 18              2024            10    02/10/2024  ...
# 19              2024            10    02/10/2024  ...
# 20              2024            10    02/10/2024  ...
# 21              2024            10    02/10/2024  ...
# 60              2024            10    05/10/2024  ...
# ...              ...           ...           ...  ...
# 104606          2024            12    26/12/2024  ...
# 104712          2024            12    26/12/2024  ...
# 104727          2024            12    27/12/2024  ...
# 104943          2024            12    30/12/2024  ...
# 104960          2024            12    30/12/2024  ...
#
#                                                   Assunto  \
# 18      Conta corrente / Salário / Poupança /Conta Apo...
# 19      Serviço de pagamento online/ via celular/ maqu...
# 20      Conta corrente / Salário / Poupança /Conta Apo...
# 21                                   Atendimento Bancário
# 60                                                    Gás
# ...                                                   ...
# 104606       Serviços por Assinatura (livros, vinhos etc)
# 104712                                  Cadastro Positivo
# 104727  Acessórios e periféricos (monitor, impressora,...
# 104943  Cartão de Crédito / Cartão de Débito / Cartão ...
# 104960             Pacote / excursão / agência de turismo
#
#                       Grupo Problema  \
# 18                 Atendimento / SAC
# 19                        Informação
# 20            Cobrança / Contestação
# 21                 Atendimento / SAC
# 60            Cobrança / Contestação
# ...                              ...
# 104606        Cobrança / Contestação
# 104712  Dados Pessoais e Privacidade
# 104727        Cobrança / Contestação
# 104943        Cobrança / Contestação
# 104960        Cobrança / Contestação
#
#                                                  Problema  \
# 18      SAC - Demanda não resolvida / não respondida /...
# 19      Informações incompletas / inadequadas sobre o ...
# 20      Dificuldade / atraso na devolução de valores p...
# 21      SAC - Demanda não resolvida / não respondida /...
# 60      Cobrança de tarifas, taxas, valores não previs...
# ...                                                   ...
# 104606  Cobrança de tarifas, taxas, valores não previs...
# 104712  Coleta, uso ou compartilhamento indevido ou nã...
# 104727  Dificuldade / atraso na devolução de valores p...
# 104943  Cálculo de juros, saldo devedor (contestação, ...
# 104960  Dificuldade / atraso na devolução de valores p...
#
#          Como Comprou Contratou Procurou Empresa  Respondida  \
# 18                     Telefone                S           S
# 19                     Telefone                S           S
# 20                     Telefone                S           S
# 21                     Telefone                S           S
# 60                     Telefone                S           S
# ...                         ...              ...         ...
# 104606                 Internet                S           S
# 104712  Não comprei / contratei                N           S
# 104727              Loja física                S           S
# 104943                 Internet                S           S
# 104960                 Internet                S           S
#
#                    Situação Avaliação Reclamação Nota do Consumidor  \
# 18      Finalizada avaliada        Não Resolvida                1.0
# 19      Finalizada avaliada        Não Resolvida                1.0
# 20      Finalizada avaliada        Não Resolvida                1.0
# 21      Finalizada avaliada        Não Resolvida                1.0
# 60      Finalizada avaliada            Resolvida                1.0
# ...                     ...                  ...                ...
# 104606  Finalizada avaliada        Não Resolvida                1.0
# 104712  Finalizada avaliada        Não Resolvida                1.0
# 104727  Finalizada avaliada        Não Resolvida                1.0
# 104943  Finalizada avaliada        Não Resolvida                3.0
# 104960  Finalizada avaliada        Não Resolvida                1.0
#
#        Análise da Recusa
# 18                   NaN
# 19                   NaN
# 20                   NaN
# 21                   NaN
# 60                   NaN
# ...                  ...
# 104606               NaN
# 104712               NaN
# 104727               NaN
# 104943               NaN
# 104960               NaN
#
# [846 rows x 30 columns]

# %% [markdown]
# **OBSEVAÇÃO :** Também é possível utilizar o método `query()` para fazer filtragem com multiplas condicionais. Porém, não é possível neste caso em específico devido a coluna **Nota do Consumidor** possuir caracteres invádios para o método (Cedilha, acentos ou espaços)

# %% [markdown]
# #### Detalhando a filtragem com múltiplas condicionais

# %% [markdown]
# A **PRIMEIRA** comparação `(df_data['UF'] == 'GO')` checa linha a linha do DataFrame, quais são aqueles cujo o estado é **GOIÁS** e nenhuma verificação de **Nota do Consumidor** é feita neste momento. Como resultado, temos uma Series de booleans com apenas esta filtragem.

# %% [markdown]
# A **SEGUNDA** comparação `(df_data['Nota do Consumidor'] <= 3.0)` checa linha a linha do DataFrame, quais são aquelas reclamações cujo a **Nota do Consumidor** é menor ou igual a **3.0** e nenhuma verificação de **UF** é feita neste momento. Como resultado, temos uma Series de booleans com apenas esta filtragem.

# %% [markdown]
# Por fim a **PRIMEIRA** e **SEGUNDA** comparação são unidas pelo operador lógico `&` **(AND)** retornando assim uma terceira Series de booleans fazendo a comparação completa.

# %% [markdown]
# Tal abordagem pode ser **INEFICIENTE**, uma vez que, para cada condição, estamos varrendo todas as linhas do DataFrame `df_data` (Ou seja, a varredura neste exemplo em específico é feita **3X**). O Pandas tentará otimizar o máximo possível por trás dos pano porém, se tivermos uma base muito grande, tal abordagem se tornará mais **INEFICIENTE** ainda.

# %% [markdown]
# Logo, poderíamos fazer a filtragem utilizando múltiplos condicionais por partes:

# %% [markdown]
# 1. Podemos fazer primeiro o filtro `(df_data['UF'] == 'GO')` trazendo assim primeiro, todos as linhas com o estado igual a **GOIÁS**

# %%
filtro_consumidores_goias = df_data[(df_data['UF'] == 'GO')]
filtro_consumidores_goias
# Out:
#                                                    Gestor Canal de Origem  \
# 18      Superintendência de Proteção e Defesa do Consu...  Plataforma Web
# 19      Superintendência de Proteção e Defesa do Consu...  Plataforma Web
# 20      Superintendência de Proteção e Defesa do Consu...  Plataforma Web
# 21      Superintendência de Proteção e Defesa do Consu...  Plataforma Web
# 26      Superintendência de Proteção e Defesa do Consu...  Plataforma Web
# ...                                                   ...             ...
# 104922  Superintendência de Proteção e Defesa do Consu...  Plataforma Web
# 104942  Superintendência de Proteção e Defesa do Consu...  Plataforma Web
# 104943  Superintendência de Proteção e Defesa do Consu...  Plataforma Web
# 104949  Superintendência de Proteção e Defesa do Consu...  Plataforma Web
# 104960  Superintendência de Proteção e Defesa do Consu...  Plataforma Web
#
#        Região  UF          Cidade Sexo        Faixa Etária  Ano Abertura  \
# 18         CO  GO        Anápolis    M  entre 21 a 30 anos          2024
# 19         CO  GO        Anápolis    M  entre 21 a 30 anos          2024
# 20         CO  GO        Anápolis    M  entre 21 a 30 anos          2024
# 21         CO  GO        Anápolis    M  entre 21 a 30 anos          2024
# 26         CO  GO         Goiânia    M  entre 21 a 30 anos          2024
# ...       ...  ..             ...  ...                 ...           ...
# 104922     CO  GO       Rio Verde    M  entre 21 a 30 anos          2024
# 104942     CO  GO         Goiânia    F  entre 31 a 40 anos          2024
# 104943     CO  GO  Senador Canedo    M  entre 31 a 40 anos          2024
# 104949     CO  GO         Goiânia    M  entre 41 a 50 anos          2024
# 104960     CO  GO        Anápolis    M  entre 31 a 40 anos          2024
#
#         Mês Abertura Data Abertura  ...  \
# 18                10    02/10/2024  ...
# 19                10    02/10/2024  ...
# 20                10    02/10/2024  ...
# 21                10    02/10/2024  ...
# 26                10    02/10/2024  ...
# ...              ...           ...  ...
# 104922            12    29/12/2024  ...
# 104942            12    30/12/2024  ...
# 104943            12    30/12/2024  ...
# 104949            12    30/12/2024  ...
# 104960            12    30/12/2024  ...
#
#                                                   Assunto  \
# 18      Conta corrente / Salário / Poupança /Conta Apo...
# 19      Serviço de pagamento online/ via celular/ maqu...
# 20      Conta corrente / Salário / Poupança /Conta Apo...
# 21                                   Atendimento Bancário
# 26      Programas de Fidelidade / Benefícios (pontos, ...
# ...                                                   ...
# 104922                                              Aéreo
# 104942  Cartão de Crédito / Cartão de Débito / Cartão ...
# 104943  Cartão de Crédito / Cartão de Débito / Cartão ...
# 104949  Crédito Pessoal e Demais Empréstimos (exceto f...
# 104960             Pacote / excursão / agência de turismo
#
#                       Grupo Problema  \
# 18                 Atendimento / SAC
# 19                        Informação
# 20            Cobrança / Contestação
# 21                 Atendimento / SAC
# 26      Dados Pessoais e Privacidade
# ...                              ...
# 104922            Vício de Qualidade
# 104942        Cobrança / Contestação
# 104943        Cobrança / Contestação
# 104949        Cobrança / Contestação
# 104960        Cobrança / Contestação
#
#                                                  Problema  \
# 18      SAC - Demanda não resolvida / não respondida /...
# 19      Informações incompletas / inadequadas sobre o ...
# 20      Dificuldade / atraso na devolução de valores p...
# 21      SAC - Demanda não resolvida / não respondida /...
# 26      Dificuldade de acesso a dados pessoais ou fina...
# ...                                                   ...
# 104922  Falta de acesso a comunicação, alimentação, ac...
# 104942              Renegociação / parcelamento de dívida
# 104943  Cálculo de juros, saldo devedor (contestação, ...
# 104949  Cobrança de tarifas, taxas, valores não previs...
# 104960  Dificuldade / atraso na devolução de valores p...
#
#          Como Comprou Contratou Procurou Empresa  Respondida  \
# 18                     Telefone                S           S
# 19                     Telefone                S           S
# 20                     Telefone                S           S
# 21                     Telefone                S           S
# 26                     Internet                S           S
# ...                         ...              ...         ...
# 104922                 Internet                S           S
# 104942              Loja física                N           S
# 104943                 Internet                S           S
# 104949  Não comprei / contratei                N           S
# 104960                 Internet                S           S
#
#                    Situação Avaliação Reclamação Nota do Consumidor  \
# 18      Finalizada avaliada        Não Resolvida                1.0
# 19      Finalizada avaliada        Não Resolvida                1.0
# 20      Finalizada avaliada        Não Resolvida                1.0
# 21      Finalizada avaliada        Não Resolvida                1.0
# 26      Finalizada avaliada            Resolvida                5.0
# ...                     ...                  ...                ...
# 104922  Finalizada avaliada            Resolvida                5.0
# 104942  Finalizada avaliada        Não Resolvida                5.0
# 104943  Finalizada avaliada        Não Resolvida                3.0
# 104949  Finalizada avaliada            Resolvida                5.0
# 104960  Finalizada avaliada        Não Resolvida                1.0
#
#        Análise da Recusa
# 18                   NaN
# 19                   NaN
# 20                   NaN
# 21                   NaN
# 26                   NaN
# ...                  ...
# 104922               NaN
# 104942               NaN
# 104943               NaN
# 104949               NaN
# 104960               NaN
#
# [4207 rows x 30 columns]

# %% [markdown]
# Logo, o DataFrame `filtro_consumidores_goias` contém 4.207 linhas

# %% [markdown]
# 2. Em seguida, aplicaremos o segundo filtro em cima do DataFrame `filtro_consumidores_goias`. Portanto, a busca dos registros com **Nota do Consumidor** menor ou igual a 3.0 (`(df_data['Nota do Consumidor'] <= 3.0)`) será feita apenas em cima dos 4.207 registros (Ao invés das 105.018 linhas anteriores).

# %%
filtro_consumidores_goias_nota_baixa = filtro_consumidores_goias[(df_data['Nota do Consumidor'] <= 3.0)]
filtro_consumidores_goias_nota_baixa
# Out:
# C:\Users\lucas\AppData\Local\Temp\ipykernel_8024\1937284871.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   filtro_consumidores_goias_nota_baixa = filtro_consumidores_goias[(df_data['Nota do Consumidor'] <= 3.0)]
#                                                    Gestor Canal de Origem  \
# 18      Superintendência de Proteção e Defesa do Consu...  Plataforma Web
# 19      Superintendência de Proteção e Defesa do Consu...  Plataforma Web
# 20      Superintendência de Proteção e Defesa do Consu...  Plataforma Web
# 21      Superintendência de Proteção e Defesa do Consu...  Plataforma Web
# 60      Superintendência de Proteção e Defesa do Consu...  Plataforma Web
# ...                                                   ...             ...
# 104606  Superintendência de Proteção e Defesa do Consu...  Plataforma Web
# 104712  Superintendência de Proteção e Defesa do Consu...  Plataforma Web
# 104727  Superintendência de Proteção e Defesa do Consu...  Plataforma Web
# 104943  Superintendência de Proteção e Defesa do Consu...  Plataforma Web
# 104960  Superintendência de Proteção e Defesa do Consu...  Plataforma Web
#
#        Região  UF                 Cidade Sexo        Faixa Etária  \
# 18         CO  GO               Anápolis    M  entre 21 a 30 anos
# 19         CO  GO               Anápolis    M  entre 21 a 30 anos
# 20         CO  GO               Anápolis    M  entre 21 a 30 anos
# 21         CO  GO               Anápolis    M  entre 21 a 30 anos
# 60         CO  GO                Goiânia    M  entre 41 a 50 anos
# ...       ...  ..                    ...  ...                 ...
# 104606     CO  GO                Goiânia    M  entre 41 a 50 anos
# 104712     CO  GO    Valparaíso de Goiás    M  entre 31 a 40 anos
# 104727     CO  GO  Santa Helena de Goiás    M  entre 31 a 40 anos
# 104943     CO  GO         Senador Canedo    M  entre 31 a 40 anos
# 104960     CO  GO               Anápolis    M  entre 31 a 40 anos
#
#         Ano Abertura  Mês Abertura Data Abertura  ...  \
# 18              2024            10    02/10/2024  ...
# 19              2024            10    02/10/2024  ...
# 20              2024            10    02/10/2024  ...
# 21              2024            10    02/10/2024  ...
# 60              2024            10    05/10/2024  ...
# ...              ...           ...           ...  ...
# 104606          2024            12    26/12/2024  ...
# 104712          2024            12    26/12/2024  ...
# 104727          2024            12    27/12/2024  ...
# 104943          2024            12    30/12/2024  ...
# 104960          2024            12    30/12/2024  ...
#
#                                                   Assunto  \
# 18      Conta corrente / Salário / Poupança /Conta Apo...
# 19      Serviço de pagamento online/ via celular/ maqu...
# 20      Conta corrente / Salário / Poupança /Conta Apo...
# 21                                   Atendimento Bancário
# 60                                                    Gás
# ...                                                   ...
# 104606       Serviços por Assinatura (livros, vinhos etc)
# 104712                                  Cadastro Positivo
# 104727  Acessórios e periféricos (monitor, impressora,...
# 104943  Cartão de Crédito / Cartão de Débito / Cartão ...
# 104960             Pacote / excursão / agência de turismo
#
#                       Grupo Problema  \
# 18                 Atendimento / SAC
# 19                        Informação
# 20            Cobrança / Contestação
# 21                 Atendimento / SAC
# 60            Cobrança / Contestação
# ...                              ...
# 104606        Cobrança / Contestação
# 104712  Dados Pessoais e Privacidade
# 104727        Cobrança / Contestação
# 104943        Cobrança / Contestação
# 104960        Cobrança / Contestação
#
#                                                  Problema  \
# 18      SAC - Demanda não resolvida / não respondida /...
# 19      Informações incompletas / inadequadas sobre o ...
# 20      Dificuldade / atraso na devolução de valores p...
# 21      SAC - Demanda não resolvida / não respondida /...
# 60      Cobrança de tarifas, taxas, valores não previs...
# ...                                                   ...
# 104606  Cobrança de tarifas, taxas, valores não previs...
# 104712  Coleta, uso ou compartilhamento indevido ou nã...
# 104727  Dificuldade / atraso na devolução de valores p...
# 104943  Cálculo de juros, saldo devedor (contestação, ...
# 104960  Dificuldade / atraso na devolução de valores p...
#
#          Como Comprou Contratou Procurou Empresa  Respondida  \
# 18                     Telefone                S           S
# 19                     Telefone                S           S
# 20                     Telefone                S           S
# 21                     Telefone                S           S
# 60                     Telefone                S           S
# ...                         ...              ...         ...
# 104606                 Internet                S           S
# 104712  Não comprei / contratei                N           S
# 104727              Loja física                S           S
# 104943                 Internet                S           S
# 104960                 Internet                S           S
#
#                    Situação Avaliação Reclamação Nota do Consumidor  \
# 18      Finalizada avaliada        Não Resolvida                1.0
# 19      Finalizada avaliada        Não Resolvida                1.0
# 20      Finalizada avaliada        Não Resolvida                1.0
# 21      Finalizada avaliada        Não Resolvida                1.0
# 60      Finalizada avaliada            Resolvida                1.0
# ...                     ...                  ...                ...
# 104606  Finalizada avaliada        Não Resolvida                1.0
# 104712  Finalizada avaliada        Não Resolvida                1.0
# 104727  Finalizada avaliada        Não Resolvida                1.0
# 104943  Finalizada avaliada        Não Resolvida                3.0
# 104960  Finalizada avaliada        Não Resolvida                1.0
#
#        Análise da Recusa
# 18                   NaN
# 19                   NaN
# 20                   NaN
# 21                   NaN
# 60                   NaN
# ...                  ...
# 104606               NaN
# 104712               NaN
# 104727               NaN
# 104943               NaN
# 104960               NaN
#
# [846 rows x 30 columns]

# %% [markdown]
# Obtemos assim então, o mesmo resultado conseguido previamente. Este método economizou busca desnecessária sendo mais eficiente em casos onde a consulta envolve bases gigantes com milhões de linhas.

# %% [markdown]
# ### Filtragem com listas

# %% [markdown]
# Se quisermos filtrar apenas as reclamações de compras feitas nas UF's **'GO'**, **'SP'**, **'RO'** e **MT**, ao invés de fazer a filtragem caso a caso podemos criar uma variável do tipo lista em python e repassar para filtragem:

# %%
lista_uf = ['GO','SP','RO','MT'] ## Criando lista contendo as UF's 'GO', 'SP', 'RO' e MT
lista_uf
# Out:
# ['GO', 'SP', 'RO', 'MT']

# %% [markdown]
# Agora também podemos repassar esta lista na filtragem do DataFrame utilizando o método `isin()` :

# %%
df_data[df_data['UF'].isin(lista_uf)]['UF'].unique()
# Out:
# array(['SP', 'MT', 'GO', 'RO'], dtype=object)

# %% [markdown]
# Também podemos utilizar lista via método `query()`, da seguinte forma:

# %%
df_data.query('UF in @lista_uf')['UF'].unique()
# Out:
# array(['SP', 'MT', 'GO', 'RO'], dtype=object)

# %% [markdown]
# Para utilizarmos uma variável dentro do método `Query()` precisamos utilizar o caractere `@nome_variavel`
