# %% [markdown]
# ### Pacotes utilizados

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Base utilizada

# %%
df_data = pd.read_csv('./Base de dados/ConsumidorGov.csv',sep = ';')

# %% [markdown]
# # Atribuindo Dados

# %% [markdown]
# ## 1. Atribuindo constantes

# %% [markdown]
# Ao fazer a atribuição de uma coluna de um DataFrame, como por exemplo á coluna `Cidade` do DataFrame `df_data`

# %%
df_data.head()
# Out:
#                                               Gestor Canal de Origem Região  \
# 0                  Secretaria Nacional do Consumidor  Plataforma Web     NE
# 1                  Secretaria Nacional do Consumidor  Plataforma Web     NE
# 2  Secretaria de Justiça e Direitos Humanos - Sec...  Plataforma Web     NE
# 3  Superintendência de Proteção e Defesa do Consu...  Plataforma Web     NE
# 4        Fundação de Proteção e Defesa do Consumidor  Plataforma Web     SE
#
#    UF    Cidade Sexo        Faixa Etária  Ano Abertura  Mês Abertura  \
# 0  AL    Maceió    F  entre 61 a 70 anos          2024            10
# 1  AL    Maceió    F  entre 61 a 70 anos          2024            10
# 2  PE    Olinda    F  entre 41 a 50 anos          2024            10
# 3  BA  Salvador    M  entre 21 a 30 anos          2024            10
# 4  SP   Guarujá    M  entre 51 a 60 anos          2024            10
#
#   Data Abertura  ...                                            Assunto  \
# 0    01/10/2024  ...                               Atendimento Bancário
# 1    01/10/2024  ...                               Atendimento Bancário
# 2    01/10/2024  ...                    Aplicativo de mobilidade urbana
# 3    01/10/2024  ...  Cartão de Crédito / Cartão de Débito / Cartão ...
# 4    01/10/2024  ...                                      Água e Esgoto
#
#            Grupo Problema                                           Problema  \
# 0       Atendimento / SAC                Descumprimento do estatuto do idoso
# 1       Atendimento / SAC                Descumprimento do estatuto do idoso
# 2  Cobrança / Contestação  Cobrança por serviço não fornecido/ em desacor...
# 3              Informação  Informações incompletas / inadequadas sobre o ...
# 4       Atendimento / SAC  Má qualidade no atendimento (descortesia / des...
#
#   Como Comprou Contratou Procurou Empresa  Respondida             Situação  \
# 0               Telefone                S           S  Finalizada avaliada
# 1               Telefone                S           S  Finalizada avaliada
# 2               Internet                S           S  Finalizada avaliada
# 3               Internet                S           S  Finalizada avaliada
# 4            Loja física                S           S  Finalizada avaliada
#
#   Avaliação Reclamação Nota do Consumidor Análise da Recusa
# 0            Resolvida                5.0               NaN
# 1            Resolvida                5.0               NaN
# 2        Não Resolvida                1.0               NaN
# 3            Resolvida                5.0               NaN
# 4            Resolvida                3.0               NaN
#
# [5 rows x 30 columns]

# %%
df_data['Cidade']
# Out:
# 0           Maceió
# 1           Maceió
# 2           Olinda
# 3         Salvador
# 4          Guarujá
#             ...
# 105013     Ibirité
# 105014     Ibirité
# 105015     Ibirité
# 105016     Ibirité
# 105017     Ibirité
# Name: Cidade, Length: 105018, dtype: object

# %%
cidade_view = df_data['Cidade']
cidade_view
# Out:
# 0           Maceió
# 1           Maceió
# 2           Olinda
# 3         Salvador
# 4          Guarujá
#             ...
# 105013     Ibirité
# 105014     Ibirité
# 105015     Ibirité
# 105016     Ibirité
# 105017     Ibirité
# Name: Cidade, Length: 105018, dtype: object

# %% [markdown]
# Esta **NÃO É UMA CÓPIA**, mas sim, uma **REFERÊNCIA** à coluna do DataFrame

# %% [markdown]
# Para fazer de fato uma cópia e criar uma Series/DataFrame que contenha não apenas uma referência, é necessário utilizar o método `copy()`

# %%
cidade_copy = df_data['Cidade'].copy()
cidade_copy
# Out:
# 0           Maceió
# 1           Maceió
# 2           Olinda
# 3         Salvador
# 4          Guarujá
#             ...
# 105013     Ibirité
# 105014     Ibirité
# 105015     Ibirité
# 105016     Ibirité
# 105017     Ibirité
# Name: Cidade, Length: 105018, dtype: object

# %% [markdown]
# E qual a diferença entre **REFERÊNCIA** e **CÓPIA**?
# Caso alguma alteração no DataFrame original `df_data` seja feita, temos que:

# %% [markdown]
# Para exemplificar utilizando a função `iloc`, esta nos permite selecionar linhas e colunas no DataFrame com base em uma posição númerica, vamos alterar então a **LINHA 0** e **COLUNA 4**, para isso podemos fazer da seguinte forma:

# %%
df_data.iloc[0,4] = 'Alterado'

# %%
df_data.head(1)
# Out:
#                               Gestor Canal de Origem Região  UF    Cidade  \
# 0  Secretaria Nacional do Consumidor  Plataforma Web     NE  AL  Alterado
#
#   Sexo        Faixa Etária  Ano Abertura  Mês Abertura Data Abertura  ...  \
# 0    F  entre 61 a 70 anos          2024            10    01/10/2024  ...
#
#                 Assunto     Grupo Problema  \
# 0  Atendimento Bancário  Atendimento / SAC
#
#                               Problema Como Comprou Contratou  \
# 0  Descumprimento do estatuto do idoso               Telefone
#
#   Procurou Empresa  Respondida             Situação Avaliação Reclamação  \
# 0                S           S  Finalizada avaliada            Resolvida
#
#   Nota do Consumidor Análise da Recusa
# 0                5.0               NaN
#
# [1 rows x 30 columns]

# %% [markdown]
# Após a alteração, se buscarmos a **CÓPIA** teremos o seguinte:

# %%
cidade_copy
# Out:
# 0           Maceió
# 1           Maceió
# 2           Olinda
# 3         Salvador
# 4          Guarujá
#             ...
# 105013     Ibirité
# 105014     Ibirité
# 105015     Ibirité
# 105016     Ibirité
# 105017     Ibirité
# Name: Cidade, Length: 105018, dtype: object

# %% [markdown]
# Após a alteração, se buscarmos a **REFERÊNCIA** teremos o seguinte:

# %%
cidade_view
# Out:
# 0         Alterado
# 1           Maceió
# 2           Olinda
# 3         Salvador
# 4          Guarujá
#             ...
# 105013     Ibirité
# 105014     Ibirité
# 105015     Ibirité
# 105016     Ibirité
# 105017     Ibirité
# Name: Cidade, Length: 105018, dtype: object

# %% [markdown]
# Nota-se então, que os valores da **CÓPIA** se mantém mesmo após a alteração do DataFrame original `df_data`, enquanto a **REFERÊNCIA** por ser um ponteiro ao DataFrame original também tem seu valor alterado.

# %% [markdown]
# A escolha entre view (referência direta) e cópia (duplicação dos dados) no pandas depende do contexto em que você está trabalhando e dos objetivos da operação. Cada abordagem tem vantagens e desvantagens e deve ser usada com cuidado para evitar comportamentos inesperados ou problemas de desempenho.

# %% [markdown]
# ## 2. Atribuindo listas ou series

# %%
n_linhas, n_colum = df_data.shape
n_linhas, n_colum
# Out:
# (105018, 30)

# %% [markdown]
# O nosso DataFram `df_data` contém 105018 linhas e 30 colunas, para fazer a alteração de uma coluna inteira precisamos de uma **Series** contendo o mesmo número de linhas existente na coluna objetivo ou seja, uma lista contendo 105018

# %% [markdown]
# Para criação destes 105018 valores de uma coluna utilizaremos **LIST COMPREHENSION**, que é uma forma de criar listas a partir de outras listas, usando uma notação matemática.

# %%
novas_cidades = [f'Cidade {i}'for i in range(n_linhas)]
len(novas_cidades) #Retorna o número de itens de um objeto, como uma lista, string, tupla, dicionário ou qualquer sequência
# Out:
# 105018

# %% [markdown]
# A quantidade de elementos na lista `novas_cidades` é igual ao número de linhas do DataFrame `df_data`, podemos então fazer a substituição dos valores da coluna **Cidade** para o novo valor

# %%
df_data['Cidade'] = novas_cidades

# %%
df_data.head()
# Out:
#                                               Gestor Canal de Origem Região  \
# 0                  Secretaria Nacional do Consumidor  Plataforma Web     NE
# 1                  Secretaria Nacional do Consumidor  Plataforma Web     NE
# 2  Secretaria de Justiça e Direitos Humanos - Sec...  Plataforma Web     NE
# 3  Superintendência de Proteção e Defesa do Consu...  Plataforma Web     NE
# 4        Fundação de Proteção e Defesa do Consumidor  Plataforma Web     SE
#
#    UF    Cidade Sexo        Faixa Etária  Ano Abertura  Mês Abertura  \
# 0  AL  Cidade 0    F  entre 61 a 70 anos          2024            10
# 1  AL  Cidade 1    F  entre 61 a 70 anos          2024            10
# 2  PE  Cidade 2    F  entre 41 a 50 anos          2024            10
# 3  BA  Cidade 3    M  entre 21 a 30 anos          2024            10
# 4  SP  Cidade 4    M  entre 51 a 60 anos          2024            10
#
#   Data Abertura  ...                                            Assunto  \
# 0    01/10/2024  ...                               Atendimento Bancário
# 1    01/10/2024  ...                               Atendimento Bancário
# 2    01/10/2024  ...                    Aplicativo de mobilidade urbana
# 3    01/10/2024  ...  Cartão de Crédito / Cartão de Débito / Cartão ...
# 4    01/10/2024  ...                                      Água e Esgoto
#
#            Grupo Problema                                           Problema  \
# 0       Atendimento / SAC                Descumprimento do estatuto do idoso
# 1       Atendimento / SAC                Descumprimento do estatuto do idoso
# 2  Cobrança / Contestação  Cobrança por serviço não fornecido/ em desacor...
# 3              Informação  Informações incompletas / inadequadas sobre o ...
# 4       Atendimento / SAC  Má qualidade no atendimento (descortesia / des...
#
#   Como Comprou Contratou Procurou Empresa  Respondida             Situação  \
# 0               Telefone                S           S  Finalizada avaliada
# 1               Telefone                S           S  Finalizada avaliada
# 2               Internet                S           S  Finalizada avaliada
# 3               Internet                S           S  Finalizada avaliada
# 4            Loja física                S           S  Finalizada avaliada
#
#   Avaliação Reclamação Nota do Consumidor Análise da Recusa
# 0            Resolvida                5.0               NaN
# 1            Resolvida                5.0               NaN
# 2        Não Resolvida                1.0               NaN
# 3            Resolvida                5.0               NaN
# 4            Resolvida                3.0               NaN
#
# [5 rows x 30 columns]

# %% [markdown]
# Para retornarmos os dados de **Cidade** originais, podemos utilizar a cópia feita na Series `cidade_copy`, esta Series foi criada e copiada antes da alteração da coluna, portanto tem os valores originais da mesma

# %%
df_data['Cidade'] = cidade_copy

# %%
df_data.head()
# Out:
#                                               Gestor Canal de Origem Região  \
# 0                  Secretaria Nacional do Consumidor  Plataforma Web     NE
# 1                  Secretaria Nacional do Consumidor  Plataforma Web     NE
# 2  Secretaria de Justiça e Direitos Humanos - Sec...  Plataforma Web     NE
# 3  Superintendência de Proteção e Defesa do Consu...  Plataforma Web     NE
# 4        Fundação de Proteção e Defesa do Consumidor  Plataforma Web     SE
#
#    UF    Cidade Sexo        Faixa Etária  Ano Abertura  Mês Abertura  \
# 0  AL    Maceió    F  entre 61 a 70 anos          2024            10
# 1  AL    Maceió    F  entre 61 a 70 anos          2024            10
# 2  PE    Olinda    F  entre 41 a 50 anos          2024            10
# 3  BA  Salvador    M  entre 21 a 30 anos          2024            10
# 4  SP   Guarujá    M  entre 51 a 60 anos          2024            10
#
#   Data Abertura  ...                                            Assunto  \
# 0    01/10/2024  ...                               Atendimento Bancário
# 1    01/10/2024  ...                               Atendimento Bancário
# 2    01/10/2024  ...                    Aplicativo de mobilidade urbana
# 3    01/10/2024  ...  Cartão de Crédito / Cartão de Débito / Cartão ...
# 4    01/10/2024  ...                                      Água e Esgoto
#
#            Grupo Problema                                           Problema  \
# 0       Atendimento / SAC                Descumprimento do estatuto do idoso
# 1       Atendimento / SAC                Descumprimento do estatuto do idoso
# 2  Cobrança / Contestação  Cobrança por serviço não fornecido/ em desacor...
# 3              Informação  Informações incompletas / inadequadas sobre o ...
# 4       Atendimento / SAC  Má qualidade no atendimento (descortesia / des...
#
#   Como Comprou Contratou Procurou Empresa  Respondida             Situação  \
# 0               Telefone                S           S  Finalizada avaliada
# 1               Telefone                S           S  Finalizada avaliada
# 2               Internet                S           S  Finalizada avaliada
# 3               Internet                S           S  Finalizada avaliada
# 4            Loja física                S           S  Finalizada avaliada
#
#   Avaliação Reclamação Nota do Consumidor Análise da Recusa
# 0            Resolvida                5.0               NaN
# 1            Resolvida                5.0               NaN
# 2        Não Resolvida                1.0               NaN
# 3            Resolvida                5.0               NaN
# 4            Resolvida                3.0               NaN
#
# [5 rows x 30 columns]

# %% [markdown]
# ## 3. Criando novas colunas

# %% [markdown]
# Para se criar uma **nova coluna** em um DataFrame é necessário atribuirmos uma lista/Series de valores ou uma constante a uma nova chave do DataFrame. Da mesmo forma da atribuição, a quantidade de valores da lista precisa ser igual ao número de linhas do DataFrame.

# %% [markdown]
# ### 3.1 Criando colunas a partir de valores constantes

# %% [markdown]
# Para criar colunas a partir de um valor constante, ou seja, todas as linhas terão o mesmo valor para esta nova coluna

# %%
df_data['Coluna Constante'] = 'Valor Constante'
df_data.head(3)
# Out:
#                                               Gestor Canal de Origem Região  \
# 0                  Secretaria Nacional do Consumidor  Plataforma Web     NE
# 1                  Secretaria Nacional do Consumidor  Plataforma Web     NE
# 2  Secretaria de Justiça e Direitos Humanos - Sec...  Plataforma Web     NE
#
#    UF  Cidade Sexo        Faixa Etária  Ano Abertura  Mês Abertura  \
# 0  AL  Maceió    F  entre 61 a 70 anos          2024            10
# 1  AL  Maceió    F  entre 61 a 70 anos          2024            10
# 2  PE  Olinda    F  entre 41 a 50 anos          2024            10
#
#   Data Abertura  ...          Grupo Problema  \
# 0    01/10/2024  ...       Atendimento / SAC
# 1    01/10/2024  ...       Atendimento / SAC
# 2    01/10/2024  ...  Cobrança / Contestação
#
#                                             Problema Como Comprou Contratou  \
# 0                Descumprimento do estatuto do idoso               Telefone
# 1                Descumprimento do estatuto do idoso               Telefone
# 2  Cobrança por serviço não fornecido/ em desacor...               Internet
#
#   Procurou Empresa Respondida             Situação  Avaliação Reclamação  \
# 0                S          S  Finalizada avaliada             Resolvida
# 1                S          S  Finalizada avaliada             Resolvida
# 2                S          S  Finalizada avaliada         Não Resolvida
#
#   Nota do Consumidor Análise da Recusa Coluna Constante
# 0                5.0               NaN  Valor Constante
# 1                5.0               NaN  Valor Constante
# 2                1.0               NaN  Valor Constante
#
# [3 rows x 31 columns]

# %% [markdown]
# Agora, a nova coluna `Coluna Constante` foi criada e ela contém em todas as 105018 linhas o mesmo valor, neste caso a string **'Constante'**

# %% [markdown]
# ### 3.2 Criando colunas a partir de uma lista

# %% [markdown]
# Para criar colunas a partir de uma lista pré definida, basta atribuir ao DataFrame o novo campo com a lista

# %%
df_data['Coluna Lista'] = range(df_data.shape[0])
df_data.head(3)
# Out:
#                                               Gestor Canal de Origem Região  \
# 0                  Secretaria Nacional do Consumidor  Plataforma Web     NE
# 1                  Secretaria Nacional do Consumidor  Plataforma Web     NE
# 2  Secretaria de Justiça e Direitos Humanos - Sec...  Plataforma Web     NE
#
#    UF  Cidade Sexo        Faixa Etária  Ano Abertura  Mês Abertura  \
# 0  AL  Maceió    F  entre 61 a 70 anos          2024            10
# 1  AL  Maceió    F  entre 61 a 70 anos          2024            10
# 2  PE  Olinda    F  entre 41 a 50 anos          2024            10
#
#   Data Abertura  ...                                           Problema  \
# 0    01/10/2024  ...                Descumprimento do estatuto do idoso
# 1    01/10/2024  ...                Descumprimento do estatuto do idoso
# 2    01/10/2024  ...  Cobrança por serviço não fornecido/ em desacor...
#
#   Como Comprou Contratou Procurou Empresa Respondida             Situação  \
# 0               Telefone                S          S  Finalizada avaliada
# 1               Telefone                S          S  Finalizada avaliada
# 2               Internet                S          S  Finalizada avaliada
#
#    Avaliação Reclamação  Nota do Consumidor Análise da Recusa  \
# 0             Resolvida                 5.0               NaN
# 1             Resolvida                 5.0               NaN
# 2         Não Resolvida                 1.0               NaN
#
#   Coluna Constante Coluna Lista
# 0  Valor Constante            0
# 1  Valor Constante            1
# 2  Valor Constante            2
#
# [3 rows x 32 columns]

# %% [markdown]
# Agora, a nova coluna `Coluna Lista` foi criada e ela contém em todas as 105018, neste caso o intervalo entre número 0 até 105017

# %% [markdown]
# Se tentarmos atribuir uma lista menor do que a quantidade de linhas totais do DataFrame teremos um problema de **Match**. Exemplo, se tentarmos atribuir uma lista de 3 itens no DataFrame `df_data`:

# %%
df_data['Lista Menor'] = [1,2,3]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[133], line 1
# ----> 1 df_data['Lista Menor'] = [1,2,3]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4311, in DataFrame.__setitem__(self, key, value)
#    4308     self._setitem_array([key], value)
#    4309 else:
#    4310     # set column
# -> 4311     self._set_item(key, value)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4524, in DataFrame._set_item(self, key, value)
#    4514 def _set_item(self, key, value) -> None:
#    4515     """
#    4516     Add series to DataFrame in specified column.
#    4517
#    (...)
#    4522     ensure homogeneity.
#    4523     """
# -> 4524     value, refs = self._sanitize_column(value)
#    4526     if (
#    4527         key in self.columns
#    4528         and value.ndim == 1
#    4529         and not isinstance(value.dtype, ExtensionDtype)
#    4530     ):
#    4531         # broadcast across multiple columns if necessary
#    4532         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5266, in DataFrame._sanitize_column(self, value)
#    5263     return _reindex_for_setitem(value, self.index)
#    5265 if is_list_like(value):
# -> 5266     com.require_length_match(value, self.index)
#    5267 arr = sanitize_array(value, self.index, copy=True, allow_2d=True)
#    5268 if (
#    5269     isinstance(value, Index)
#    5270     and value.dtype == "object"
#    (...)
#    5273     # TODO: Remove kludge in sanitize_array for string mode when enforcing
#    5274     # this deprecation
#
# File ~\anaconda3\Lib\site-packages\pandas\core\common.py:573, in require_length_match(data, index)
#     569 """
#     570 Check the length of data matches the length of the index.
#     571 """
#     572 if len(data) != len(index):
# --> 573     raise ValueError(
#     574         "Length of values "
#     575         f"({len(data)}) "
#     576         "does not match length of index "
#     577         f"({len(index)})"
#     578     )
#
# ValueError: Length of values (3) does not match length of index (105018)

# %% [markdown]
# ### 3.3 Criando colunas a partir de outra coluna

# %% [markdown]
# Uma coluna pode ser criado com base em calculos matemátios e/ou condicionais dependentes de outros campos. Por exemplo, se tentarmos criar uma nova coluna chamada `Nova Nota Consumidor` onde o valor dela é a multiplicação do campo `Nota Consumidor` * **2**, fariamos o seguintes:

# %%
df_data['Nova Nota do Consumidor'] = df_data['Nota do Consumidor'] * 2
df_data.head(3)
# Out:
#                                               Gestor Canal de Origem Região  \
# 0                  Secretaria Nacional do Consumidor  Plataforma Web     NE
# 1                  Secretaria Nacional do Consumidor  Plataforma Web     NE
# 2  Secretaria de Justiça e Direitos Humanos - Sec...  Plataforma Web     NE
#
#    UF  Cidade Sexo        Faixa Etária  Ano Abertura  Mês Abertura  \
# 0  AL  Maceió    F  entre 61 a 70 anos          2024            10
# 1  AL  Maceió    F  entre 61 a 70 anos          2024            10
# 2  PE  Olinda    F  entre 41 a 50 anos          2024            10
#
#   Data Abertura  ... Como Comprou Contratou Procurou Empresa Respondida  \
# 0    01/10/2024  ...               Telefone                S          S
# 1    01/10/2024  ...               Telefone                S          S
# 2    01/10/2024  ...               Internet                S          S
#
#               Situação Avaliação Reclamação  Nota do Consumidor  \
# 0  Finalizada avaliada            Resolvida                 5.0
# 1  Finalizada avaliada            Resolvida                 5.0
# 2  Finalizada avaliada        Não Resolvida                 1.0
#
#    Análise da Recusa Coluna Constante Coluna Lista Nova Nota do Consumidor
# 0                NaN  Valor Constante            0                    10.0
# 1                NaN  Valor Constante            1                    10.0
# 2                NaN  Valor Constante            2                     2.0
#
# [3 rows x 33 columns]

# %% [markdown]
# ### 3.4 Criando colunas condicionais

# %%
df_data['Coluna Condicional'] = np.where(df_data['Nova Nota do Consumidor'] >= 5, 'Boa','Ruim')
df_data.head(3)
# Out:
#                                               Gestor Canal de Origem Região  \
# 0                  Secretaria Nacional do Consumidor  Plataforma Web     NE
# 1                  Secretaria Nacional do Consumidor  Plataforma Web     NE
# 2  Secretaria de Justiça e Direitos Humanos - Sec...  Plataforma Web     NE
#
#    UF  Cidade Sexo        Faixa Etária  Ano Abertura  Mês Abertura  \
# 0  AL  Maceió    F  entre 61 a 70 anos          2024            10
# 1  AL  Maceió    F  entre 61 a 70 anos          2024            10
# 2  PE  Olinda    F  entre 41 a 50 anos          2024            10
#
#   Data Abertura  ... Procurou Empresa Respondida             Situação  \
# 0    01/10/2024  ...                S          S  Finalizada avaliada
# 1    01/10/2024  ...                S          S  Finalizada avaliada
# 2    01/10/2024  ...                S          S  Finalizada avaliada
#
#   Avaliação Reclamação Nota do Consumidor  Análise da Recusa  \
# 0            Resolvida                5.0                NaN
# 1            Resolvida                5.0                NaN
# 2        Não Resolvida                1.0                NaN
#
#    Coluna Constante Coluna Lista Nova Nota do Consumidor Coluna Condicional
# 0   Valor Constante            0                    10.0                Boa
# 1   Valor Constante            1                    10.0                Boa
# 2   Valor Constante            2                     2.0               Ruim
#
# [3 rows x 34 columns]

# %% [markdown]
# ### 3.4 Dropando campos

# %% [markdown]
# Para fazer o drop de campos que não serão utilizados no DataFrame, basta utilizar o método `drop()`, da seguinte forma:

# %%
df_data.drop(['Coluna Constante','Coluna Lista','Nova Nota do Consumidor','Coluna Condicional'], axis=1, inplace=True)
df_data.head(3)
# Out:
#                                               Gestor Canal de Origem Região  \
# 0                  Secretaria Nacional do Consumidor  Plataforma Web     NE
# 1                  Secretaria Nacional do Consumidor  Plataforma Web     NE
# 2  Secretaria de Justiça e Direitos Humanos - Sec...  Plataforma Web     NE
#
#    UF  Cidade Sexo        Faixa Etária  Ano Abertura  Mês Abertura  \
# 0  AL  Maceió    F  entre 61 a 70 anos          2024            10
# 1  AL  Maceió    F  entre 61 a 70 anos          2024            10
# 2  PE  Olinda    F  entre 41 a 50 anos          2024            10
#
#   Data Abertura  ...                          Assunto          Grupo Problema  \
# 0    01/10/2024  ...             Atendimento Bancário       Atendimento / SAC
# 1    01/10/2024  ...             Atendimento Bancário       Atendimento / SAC
# 2    01/10/2024  ...  Aplicativo de mobilidade urbana  Cobrança / Contestação
#
#                                             Problema Como Comprou Contratou  \
# 0                Descumprimento do estatuto do idoso               Telefone
# 1                Descumprimento do estatuto do idoso               Telefone
# 2  Cobrança por serviço não fornecido/ em desacor...               Internet
#
#   Procurou Empresa  Respondida             Situação Avaliação Reclamação  \
# 0                S           S  Finalizada avaliada            Resolvida
# 1                S           S  Finalizada avaliada            Resolvida
# 2                S           S  Finalizada avaliada        Não Resolvida
#
#   Nota do Consumidor Análise da Recusa
# 0                5.0               NaN
# 1                5.0               NaN
# 2                1.0               NaN
#
# [3 rows x 30 columns]
